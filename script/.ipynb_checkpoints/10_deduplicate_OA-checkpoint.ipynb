# %%
import pandas as pd
import os 
import glob

dir_path = "/Users/simon/Documents/repo/cities-learning"

# Create the full search pattern
file_pattern = os.path.join(dir_path, "data/OpenAlex/03_translated/city_works_df_translated_*.feather")

# Find all matching files
files = glob.glob(file_pattern)

# Read all the files into a list of DataFrames
dfs = [pd.read_feather(file) for file in files]

# Optionally, concatenate them into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# %%
print(combined_df.columns)

combined_df["abstract"][combined_df["abstract_filtering"] == "no translatable lang"]
print(combined_df["abstract_filtering"].unique())
print(f"abstracts entirely english: " + str(sum(combined_df["abstract_filtering"] == "already english")))
print(f"abstracts mostly english: " + str(sum(combined_df["abstract_filtering"] == "mostly english")))
print(f"abstracts filtered english part: " + str(sum(combined_df["abstract_filtering"] == "filtered english")))
print(f"abstracts translated: " + str(sum(combined_df["abstract_filtering"] == "translated full text")))
print(f"abstracts with no translatable lang: " + str(sum(combined_df["abstract_filtering"] == "no translatable lang")))
print(f"abstracts unknown: " + str(sum(combined_df["abstract_filtering"] == "unknown")))
# Out:
# Index(['id', 'title', 'abstract', 'authors', 'publication_year',
#        'cited_by_count', 'cited_by_api_url', 'doi', 'type', 'abstract_en',
#        'abstract_languages', 'abstract_filtering'],
#       dtype='object')
# ['already english' 'mostly english' 'filtered english'
#  'translated full text' 'no translatable lang' 'unknown']
# abstracts entirely english: 197310
# abstracts mostly english: 31567
# abstracts filtered english part: 11751
# abstracts translated: 2003
# abstracts with no translatable lang: 11241
# abstracts unknown: 7

# %%
pre_count = len(combined_df)
print("observations before exact deduplication:" +  str())
combined_df = combined_df.drop_duplicates(subset=["id"])
duplicates_dropped = pre_count-len(combined_df)
print("exact deduplicates dropped:" + str(duplicates_dropped))
print("observations after exact deduplication:" + str(len(combined_df)))
print("Observations with missing abstracts after exact deduplication: " + str(combined_df["abstract"].isna().sum()))
print("Observations with missing titles after exact deduplication: " + str(combined_df["title"].isna().sum()))
print("Observations with missing titles after exact deduplication: " + str(combined_df["authors"].isna().sum()))
print("Observations with missing titles after exact deduplication: " + str(combined_df["publication_year"].isna().sum()))
print(combined_df[combined_df["abstract"].isna()])
# Out:
# observations before exact deduplication:
# exact deduplicates dropped:0
# observations after exact deduplication:253879
# Observations with missing abstracts after exact deduplication: 11208
# Observations with missing titles after exact deduplication: 340
# Observations with missing titles after exact deduplication: 4940
# Observations with missing titles after exact deduplication: 1
#                                       id  \
# 162     https://openalex.org/W3126389254
# 445     https://openalex.org/W2967604920
# 600     https://openalex.org/W2889888272
# 845     https://openalex.org/W2344857369
# 1005    https://openalex.org/W2914906502
# ...                                  ...
# 254102   https://openalex.org/W620606110
# 254104  https://openalex.org/W3035199203
# 254105  https://openalex.org/W4243874459
# 254108  https://openalex.org/W4252554165
# 254109  https://openalex.org/W2381581489
#
#                                                     title abstract  \
# 162     Beth SchaeferCaniglia, BeatriceFrank, John L.K...     None
# 445     Energy performance analysis of mandatory desig...     None
# 600     Evaluation of China’s Mercury Emission Control...     None
# 845     Reviews: Asphalt Nation: How the Automobile To...     None
# 1005    Brooklyn College Library LibGuides Home: PRLS ...     None
# ...                                                   ...      ...
# 254102  An investigation of carbon footprint reduction...     None
# 254104  The low carbon city planning by the Tamachi sm...     None
# 254105  Scenario analysis of low-carbon development po...     None
# 254108  15: Low-Carbon Logistics Network for Smart Cit...     None
# 254109  Practice and Reflection of Low-carbon Urban Pl...     None
#
#                                                   authors  publication_year  \
# 162                                           Jieling Liu            2021.0
# 445                             Ng Osorio, José Alejandro            2019.0
# 600     Wei Zhang, Genchong Zheng, Long Chen, Huanhuan...            2017.0
# 845     Jennifer Adams, Chad Staddon, Margaret Walton‐...            1999.0
# 1005                                            Amy Wolfe            2018.0
# ...                                                   ...               ...
# 254102                                        Jasper Dick            2012.0
# 254104                 T Kunitomo, Akiko Takeda, M Bansai            2017.0
# 254105              Peng Wang, Beibei Cheng, Daiqing Zhao            2013.0
# 254108                 Harpreet Kaur, Surya Prakash Singh            2017.0
# 254109                                     Guiyang Zhuang            2011.0
#
#         cited_by_count                                   cited_by_api_url  \
# 162                0.0  https://api.openalex.org/works?filter=cites:W3...
# 445                0.0  https://api.openalex.org/works?filter=cites:W2...
# 600                0.0  https://api.openalex.org/works?filter=cites:W2...
# 845                0.0  https://api.openalex.org/works?filter=cites:W2...
# 1005               0.0  https://api.openalex.org/works?filter=cites:W2...
# ...                ...                                                ...
# 254102             0.0  https://api.openalex.org/works?filter=cites:W6...
# 254104             0.0  https://api.openalex.org/works?filter=cites:W3...
# 254105             0.0  https://api.openalex.org/works?filter=cites:W4...
# 254108             0.0  https://api.openalex.org/works?filter=cites:W4...
# 254109             0.0  https://api.openalex.org/works?filter=cites:W2...
#
#                                              doi  type abstract_en  \
# 162             https://doi.org/10.1002/wmh3.383  None
# 445            https://doi.org/10.26153/tsw/2223  None
# 600                                         None  None
# 845              https://doi.org/10.1068/a312249  None
# 1005                                        None  None
# ...                                          ...   ...         ...
# 254102                                      None  None
# 254104                                      None  None
# 254105        https://doi.org/10.2495/itie131422  None
# 254108  https://doi.org/10.1201/9781315156040-16  None
# 254109                                      None  None
#
#        abstract_languages    abstract_filtering
# 162                        no translatable lang
# 445                        no translatable lang
# 600                        no translatable lang
# 845                        no translatable lang
# 1005                       no translatable lang
# ...                   ...                   ...
# 254102                     no translatable lang
# 254104                     no translatable lang
# 254105                     no translatable lang
# 254108                     no translatable lang
# 254109                     no translatable lang
#
# [11208 rows x 12 columns]

# %%
from semhash import SemHash
import numpy as np

filtered_df = combined_df.copy()

cols_to_string = ["title", "authors", "abstract_en", "publication_year"]

for col in cols_to_string:
    filtered_df[col] = filtered_df[col].astype(str)

# Convert to list of dictionaries
records = filtered_df[["id", "title", "abstract_en", "authors", "publication_year"]].to_dict(orient="records")

# Now count missing values
missing_titles = sum(1 for rec in records if rec["title"] == "None")
missing_abstracts = sum(1 for rec in records if rec["abstract_en"] == "None")
missing_authors = sum(1 for rec in records if rec["authors"] == "None")
missing_pub_years = sum(1 for rec in records if rec["publication_year"] == "None")

print(f"Missing abstracts: {missing_abstracts}")
print(f"Missing titles: {missing_titles}")
print(f"Missing authors: {missing_authors}")
print(f"Missing publication years: {missing_pub_years}")
# Out:
# Missing abstracts: 0
# Missing titles: 340
# Missing authors: 4940
# Missing publication years: 0

# %%
from sentence_transformers import SentenceTransformer
import torch

for rec in records:
    rec['text'] = f"{rec['title']} {rec['abstract_en']}"

# Load model
model = SentenceTransformer("all-MiniLM-L6-v2", device="cuda" if torch.cuda.is_available() else "cpu")

# initialize SemHash with that model
semhash = SemHash.from_records(records=records, columns=["text", "authors"], 
                               model=model
                              )

threshold = 0.88
dedup_result = semhash.self_deduplicate(threshold=threshold)

# %%
# Create a class so that I can call attributes 
from dataclasses import dataclass

@dataclass
class DuplicateRecord:
    record: dict
    exact: bool
    duplicates: list
    
# A list to collect records with no valid duplicates
non_matching_records = []

# A new list to store filtered duplicates that meet the match criteria
filtered_duplicates = []

# Iterate through all duplicate records
for dup in dedup_result.duplicates:
    original = dup.record
    original_year = int(float(original.get("publication_year")))

    # List to hold valid matches for this original record
    valid_matches = []

    for rec, score in dup.duplicates:
        duplicate_year = int(float(rec.get("publication_year")))

        has_abstract = rec.get('abstract_en') and rec['abstract_en'].strip().lower() != "none"
        has_title = rec.get('title') and rec['title'].strip().lower() != "none"
        has_authors = rec.get('authors') and rec['authors'].strip().lower() != "none"
        
        close_years = abs(duplicate_year - original_year) <= 1
        match = False

        # Apply matching rules
        if close_years and has_abstract and has_authors and has_title and score > 0.9:
            match = True
        elif close_years and has_abstract and has_authors and not has_title and score > 0.9:
            match = True
        elif close_years and has_abstract and not has_authors and has_title and score > 0.92:
            match = True
        elif close_years and not has_abstract and has_authors and has_title and score > 0.9:
            match = True
        elif close_years and has_abstract and not has_title and has_authors and score > 0.9:
            match = True
        elif close_years and has_abstract and not has_title and not has_authors and score > 0.9:
            match = True
        elif close_years and not has_abstract and has_title and not has_authors and score > 0.92:
            match = True
        # has to be specified for completeness but there are no applicable observations, here
        elif close_years and not has_abstract and not has_title and has_authors and score > 0.99:
            match = True
        elif close_years and not has_abstract and not has_authors and not has_title and score > 0.99:
            match = True

        if match:
            valid_matches.append((rec, score))

    # Store record only if it has valid matches
    if valid_matches:
        filtered_duplicates.append(
            DuplicateRecord(record=original, duplicates=valid_matches, exact=False)
        )
    else:
        non_matching_records.append(original)

# %%
# check that the numbers are right:
print(f"Duplicates based on more restrictive criteria with individual thresholds: {sum(1 for record in filtered_duplicates)}")
print(f"Number of duplicates that are likely falsely detected as such: {len(non_matching_records)}")
print(f"Restricted duplicates and those duplicates that do not belong to the restricted duplicates but had initially been predicted as such = {sum(1 for record in filtered_duplicates) + len(non_matching_records)} must be equal to the initial number of duplicates = {len(dedup_result.duplicates)}")
# Out:
# Duplicates based on more restrictive criteria with individual thresholds: 19316
# Number of duplicates that are likely falsely detected as such: 3090
# Restricted duplicates and those duplicates that do not belong to the restricted duplicates but had initially been predicted as such = 22406 must be equal to the initial number of duplicates = 22406

# %%
# add false positive duplicates to the deduplicated list
filtered_deduplicated = dedup_result.deduplicated.copy()
filtered_deduplicated.extend(non_matching_records)

# %%
## transform to dfs 
# SemHash: duplicates and the deduplicated records from the semhashing as dataframes
deduplicated_hash_df = pd.DataFrame(dedup_result.deduplicated)
dup_records = [dup.record for dup in dedup_result.duplicates]
duplicates_hash_df = pd.DataFrame(dup_records)
# customized additional filtering:
filtered_duplicates_df = pd.DataFrame(filtered_duplicates)
filtered_deduplicated_df = pd.DataFrame(filtered_deduplicated)

# %%
# remove all those ids that are insided 
print("----------SemHash numbers-------------------------------------------------------------------------")
print(f"SemHash deduplicated: {len(deduplicated_hash_df)}")
print(f"SemHash duplicates: {len(duplicates_hash_df)}")
print("----------Restricted filtering numbers------------------------------------------------------------")
print(f"Restricted deduplicated: {len(filtered_duplicates)}")
print(f"Restricted duplicates: {len(filtered_deduplicated)}")
print("----------Additional------------------------------------------------------------------------------")
print(f"SemHash duplicates that are no duplicates according to restricted criteria: {len(duplicates_hash_df)- len(filtered_duplicates)}")
print(f"All wrongly assigned SemHash duplicates are correctly reasssigned: {len(filtered_deduplicated)-len(deduplicated_hash_df) == len(duplicates_hash_df) - len(filtered_duplicates)}")
print(f"Final percentage of removed: {(len(filtered_duplicates_df)/ (len(deduplicated_hash_df) + len(duplicates_hash_df))):.2%}")
# Out:
# ----------SemHash numbers-------------------------------------------------------------------------
# SemHash deduplicated: 231473
# SemHash duplicates: 22406
# ----------Restricted filtering numbers------------------------------------------------------------
# Restricted deduplicated: 19316
# Restricted duplicates: 234563
# ----------Additional------------------------------------------------------------------------------
# SemHash duplicates that are no duplicates according to restricted criteria: 3090
# All wrongly assigned SemHash duplicates are correctly reasssigned: True
# Final percentage of removed: 7.61%

# %%
def filter_duplicates_by_na_fields(duplicates, require_abstract=True, require_title=True, require_authors=True):
    """
    Filters and prints the 10 duplicate groups with the lowest average score,
    where the original record meets the specified NA conditions.
    
    Args:
        duplicates (list): List of DuplicateRecord objects.
        require_abstract (bool): If True, abstract must NOT be NA.
        require_title (bool): If True, title must NOT be NA.
        require_authors (bool): If True, authors must NOT be NA.
    """
    if not duplicates:
        print("No duplicates to check.")
        return

    filtered = []

    for dup in duplicates:
        has_abstract = dup.record.get('abstract_en') and dup.record['abstract_en'].strip().lower() != "none"
        has_title = dup.record.get('title') and dup.record['title'].strip().lower() != "none"
        has_authors = dup.record.get('authors') and dup.record['authors'].strip().lower() != "none"

        condition = (has_abstract == require_abstract) and (has_title == require_title) and (has_authors == require_authors)

        if condition and dup.duplicates:
            avg_score = sum(score for _, score in dup.duplicates) / len(dup.duplicates)
            filtered.append((avg_score, dup))

    if not filtered:
        print("\nNo duplicates found based on the specified NA conditions.")
        return

    # Sort by average score and take the 10 lowest
    filtered.sort(key=lambda x: x[0])
    filtered = filtered[:10]

    for avg_score, dup in filtered:
        print("\n=== DUPLICATE RECORD ===")
        print(f"Original Title : {dup.record.get('title', '')[:100]}")
        print(f"Authors        : {dup.record.get('authors', '')[:100]}")
        print(f"Abstract       : {dup.record.get('abstract_en', '')[:100]}")
        print(f"Year           : {str(dup.record.get('publication_year', ''))[:100]}")
        print(f"Exact Match    : {dup.exact}")
        print(f"Avg. Score     : {avg_score:.3f}")
        print("Duplicates:")
        for rec, score in dup.duplicates:
            print(f"  - Title   : {rec.get('title', '')[:100]}")
            print(f"    Authors : {rec.get('authors', '')[:100]}")
            print(f"    Abstract: {rec.get('abstract_en', '')[:100]}")
            print(f"    Year    : {str(rec.get('publication_year', ''))[:100]}")
            print(f"    Score   : {score:.3f}")

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=True, require_authors=True)
# Out:
# === DUPLICATE RECORD ===
# Original Title : Climate change and the future of Australia's country towns
# Authors        : Andrew Beer, Selina Tually, Michael Kroehn, John Martin, Rolf Gerritsen, Mike Taylor, Michelle Graym
# Abstract       : This chapter presents the future of Australia's country towns in the context of anticipated climate
# Year           : 2014.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Australia’s country towns 2050: what will a climate adapted settlement pattern look like?
#     Authors : Andrew Beer, Selina Tually, Michael Kroehn, John Martin, Rolf Gerritsen, Michael Taylor, Michelle Gr
#     Abstract: Abstract This report considers the impact of anticipated climate change on Australia’s inland towns
#     Year    : 2013.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Cool Surface Strategies with an Emphasis on the Materials Dimension: A Review
# Authors        : Chaimae Mourou, Montserrat Zamorano, Diego P. Ruíz, María Martín-Morales
# Abstract       : The need to tackle the urban heat island effect demands the implementation of cool surfaces as a mit
# Year           : 2022.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Characterization of Ceramic Tiles Coated with Recycled Waste Glass Particles to Be Used for Cool Roo
#     Authors : Chaimae Mourou, Montserrat Zamorano, Diego P. Ruíz, María Martín-Morales
#     Abstract: The use of recycled materials such as waste glass (WG) in the ceramic industry is considered as a pl
#     Year    : 2023.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Analysing the treatment of environmental justice and nature-based solutions in the Urban Climate Act
# Authors        : Jarumi Kato-Huerta, Davide Geneletti
# Abstract       : Urban Climate Action Plans are instruments increasingly being used by governments to identify vulner
# Year           : 2023.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Environmental justice implications of nature-based solutions in urban areas: A systematic review of
#     Authors : Jarumi Kato-Huerta, Davide Geneletti
#     Abstract: Environmental justice (EJ) addresses the unequal distribution of environmental goods and harms and p
#     Year    : 2022.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Aircraft-Based AirCore Sampling for Estimates of N<sub>2</sub>O and CH<sub>4</sub> Emissions
# Authors        : Xin Tong, Steven van Heuven, Bert Scheeren, Bert Kers, Ronald Hutjes, Huilin Chen
# Abstract       : Airborne measurements offer an effective way to quantify urban emissions of greenhouse gases (GHGs).
# Year           : 2023.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Urban emissions of N2O and CH4 estimated from airborne active AirCore observations&amp;#160;
#     Authors : Xin Tong, Steven van Heuven, Bert Scheeren, Bert Kers, Ronald Hutjes, Huilin Chen
#     Abstract: &amp;lt;p&amp;gt;Urban emissions of N&amp;lt;sub&amp;gt;2&amp;lt;/sub&amp;gt;O and CH&amp;lt;sub&amp
#     Year    : 2022.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : EFFECT OF URBANIZATION ON WINTER AIR TEMPERATURE IN HU′NAN
# Authors        : Wang Ai-zhen
# Abstract       : The impact of natural factors such as latitude, altitude and longitude on air temperature in city st
# Year           : 2009.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Study on the Correlation among the Decadal Changes of Winter Temperature and Heat Island Effect and
#     Authors : Wang Ai-zhen
#     Abstract: Based on the records of the average temperature in winter for 43 years(1962～2004) from 83 ground met
#     Year    : 2008.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Report sets out Manchester's progress towards zero-carbon goal
# Authors        : Oliver Wright
# Abstract       : Manchester City Council’s Executive will be updated on the latest progress towards Manchester’s zero
# Year           : 2019.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Manchester's zero carbon plan to fight climate change moves forward
#     Authors : Oliver Wright
#     Abstract: A report outlining how Manchester can meet its aim to become a zero carbon city by 2038 will  be con
#     Year    : 2019.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Effects of Climate in 2009 on Animal Husbandry in Hulunbeir City
# Authors        : Zhu Meng-fen
# Abstract       : In Hulunbeier in 2009,returning green stage of forage grasses was delayed,which retarded their norma
# Year           : 2010.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Analysis on the Influence of Climate on Animal Husbandry in Hulunbeir in 2010
#     Authors : Zhu Meng-fen
#     Abstract: By dint of precipitation,temperature,sunshine hours,gale days in six stations from 1961 to 2010,stat
#     Year    : 2011.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Temporal and spatial variations of urban heat island effect in Beijing using ASTER and TM data
# Authors        : Mingyi Du, Qianwei Wang, Guoyin Cai
# Abstract       : More and more questions were emerged with the development of Beijing's urbanization. One of them is
# Year           : 2009.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Monitoring of seasonal change of urban heat island effect in Beijing using Aster data
#     Authors : Guoyin Cai, Mingyi Du, Yong Xue
#     Abstract: The urban heat island (UHI) refers to the temperature rise of any man-made area, which can make it d
#     Year    : 2008.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Microscale Heat Island Characterization of Rigid Pavements
# Authors        : Sushobhan Sen, Jeffery R. Roesler
# Abstract       : Rigid pavements have an impact on the urban heat island (UHI) and hence the surrounding environment
# Year           : 2017.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Pavement geometry in microscale urban heat Islands
#     Authors : Sushobhan Sen, Jeffery R. Roesler
#     Abstract:
#     Year    : 2017.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Parametric evaluation of heat transfer mechanisms in a WUI fire scenario
# Authors        : Cesare Fiorini, Hélder D. Craveiro, Aldina Santiago, Luís Laím, Luís Simões da Silva
# Abstract       : Background Wildland–urban interface (WUI) fires are becoming more frequent and catastrophic as they
# Year           : 2023.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Microscale fire modelling at the Wildland-Urban Interface
#     Authors : Cesare Fiorini, Hélder D. Craveiro, Aldina Santiago, Luís Laím, Luís Simões da Silva
#     Abstract: The direct and indirect impacts of Wildland-Urban Interface fires on infrastructures and communities
#     Year    : 2022.0
#     Score   : 0.880

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=True, require_authors=False)
# Out:
# === DUPLICATE RECORD ===
# Original Title : Managing the transition to a climate-neutral economy in regions and cities
# Authors        : None
# Abstract       : Regions and cities play an important role in achieving climate-neutrality by the middle of the 21st
# Year           : 2020.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : Governance of Climate Responsive Cities
#     Authors : None
#     Abstract:
#     Year    : 2021.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Urban adaptation to climate change in Europe 2016
# Authors        : None
# Abstract       : European Environment Agency, May 2012, 148 p. (EEA Report...
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.880
# Duplicates:
#   - Title   : CLIMATE CHANGE AND CITY ENVIRONMENTS
#     Authors : None
#     Abstract:
#     Year    : 2017.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Building climate-resilient infrastructure with regions and cities
# Authors        : None
# Abstract       : This chapter explores how taking an integrated approach can help create more climate-resilient regio
# Year           : 2024.0
# Exact Match    : False
# Avg. Score     : 0.881
# Duplicates:
#   - Title   : Resilient infrastructure as an accelerator of transformative climate action in cities
#     Authors : None
#     Abstract:
#     Year    : 2024.0
#     Score   : 0.881
#
# === DUPLICATE RECORD ===
# Original Title : The urbanization of climate change: Responding to a new global challenge
# Authors        : None
# Abstract       : Cities ﬁ nd themselves on the front lines of climate change.2 The direct effects
# of a warming earth
# Year           : 2013.0
# Exact Match    : False
# Avg. Score     : 0.886
# Duplicates:
#   - Title   : (International Development Cooperation for Urban Response to Climate Change: Issues and Implications
#     Authors : None
#     Abstract:
#     Year    : 2014.0
#     Score   : 0.886
#
# === DUPLICATE RECORD ===
# Original Title : The Impacts of Climate and Environmental Change on Cities
# Authors        : None
# Abstract       : Reviews the secondary literature on how each of the climate change-related stresses has affected urb
# Year           : 2023.0
# Exact Match    : False
# Avg. Score     : 0.888
# Duplicates:
#   - Title   : The Impact of Cities on Climate and the Environment
#     Authors : None
#     Abstract:
#     Year    : 2023.0
#     Score   : 0.888
#
# === DUPLICATE RECORD ===
# Original Title : Introduction
# Authors        : None
# Abstract       : Climate change is one of the most challenging issues of our time. As key sites in the production and
# Year           : 2010.0
# Exact Match    : False
# Avg. Score     : 0.891
# Duplicates:
#   - Title   : Cities and Climate Change : An Urgent Agenda
#     Authors : None
#     Abstract:
#     Year    : 2010.0
#     Score   : 0.903
#   - Title   : CITIES AND THE INTERNATIONAL CLIMATE CHANGE FRAMEWORK
#     Authors : None
#     Abstract:
#     Year    : 2011.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : Microclimate
# Authors        : None
# Abstract       : City microclimates are described, including the Urban Heat Island Effect. There is also consideratio
# Year           : 2016.0
# Exact Match    : False
# Avg. Score     : 0.891
# Duplicates:
#   - Title   : A variety of approaches are being developed to minimize urban heat island effect
#     Authors : None
#     Abstract:
#     Year    : 2015.0
#     Score   : 0.891
#
# === DUPLICATE RECORD ===
# Original Title : Introduction
# Authors        : None
# Abstract       : This chapter provides an overview of the economics of a 'green city' and of the urban war against cl
# Year           : 2017.0
# Exact Match    : False
# Avg. Score     : 0.895
# Duplicates:
#   - Title   : Climate Change and the City
#     Authors : None
#     Abstract:
#     Year    : 2017.0
#     Score   : 0.901
#   - Title   : CLIMATE CHANGE AND CITY ENVIRONMENTS
#     Authors : None
#     Abstract:
#     Year    : 2017.0
#     Score   : 0.888
#
# === DUPLICATE RECORD ===
# Original Title : A Catalogue of Nature-Based Solutions for Urban Resilience
# Authors        : None
# Abstract       : No AccessCity Development Strategy8 Nov 2021A Catalogue of Nature-Based Solutions for Urban Resilien
# Year           : 2021.0
# Exact Match    : False
# Avg. Score     : 0.895
# Duplicates:
#   - Title   : An application of Nature-based Solutions in urban planning: a guideline for practitioners to enhance
#     Authors : None
#     Abstract:
#     Year    : 2021.0
#     Score   : 0.895
#
# === DUPLICATE RECORD ===
# Original Title : Building Resilience of the Urban Poor
# Authors        : None
# Abstract       : This report explains how rising climate and disaster risk can increase the vulnerability of Asia and
# Year           : 2022.0
# Exact Match    : False
# Avg. Score     : 0.897
# Duplicates:
#   - Title   : Urban Resilience to Climate Change
#     Authors : None
#     Abstract:
#     Year    : 2023.0
#     Score   : 0.908
#   - Title   : Urban Climate Resilience
#     Authors : None
#     Abstract:
#     Year    : 2022.0
#     Score   : 0.896
#   - Title   : Urban resilience at a crossroads: multilevel climate action
#     Authors : None
#     Abstract:
#     Year    : 2023.0
#     Score   : 0.887

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=False, require_authors=True)
# Out:
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : M. Sampath Kumar, G Swathi
# Abstract       : Ground water can be polluted in numerous ways in spite of the protective mantle which nature has pro
# Year           : 2014.0
# Exact Match    : False
# Avg. Score     : 0.887
# Duplicates:
#   - Title   : Unplanned Municipal Solid Waste Dumps and Their Impact on Water Quality - A Case Study from Visakhap
#     Authors : M. Rajesh Kumar, Gundala Swathi
#     Abstract: Ground water can be polluted in numerous ways in spite of the protective mantle which nature has pro
#     Year    : 2014.0
#     Score   : 0.887
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Birhanu Gizaw, Endegena Aynalem
# Abstract       : Population growth coupled with increase in demand for food, domestication and scientific cultivation
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.889
# Duplicates:
#   - Title   : Traditional Knowledge on Mushroom Consumption Habits of Amhara Region in Four Selected Districts - M
#     Authors : Birhanu Gizaw
#     Abstract: Population growth coupled with increase in demand for food, domestication and scientific cultivation
#     Year    : 2018.0
#     Score   : 0.889
#   - Title   : Traditional Knowledge on Mushroom consumption habits of Amhara region in four selected districts; -
#     Authors : Birhanu Gizaw
#     Abstract: Population growth coupled with increase in demand for food, domestication and scientific cultivation
#     Year    : 2018.0
#     Score   : 0.889
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Kevin Canfield
# Abstract       : Vandana Singh Ambiguity Machines and Other Stories Easthampton, Massachusetts. Small Beer Press. 201
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.892
# Duplicates:
#   - Title   : The Arid Sky by Emiliano Monge
#     Authors : Kevin Canfield
#     Abstract: Vandana Singh Ambiguity Machines and Other Stories Easthampton, Massachusetts. Small Beer Press. 201
#     Year    : 2018.0
#     Score   : 0.892
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Jennifer Kerns
# Abstract       : 132 OHQ vol. 119, no. 1 and its documents, which are more familiar to readers and other legal histor
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.917
# Duplicates:
#   - Title   : Making the White Man's West: Whiteness and the Creation of the American West by Jason Pierce
#     Authors : Jennifer Kerns
#     Abstract: 132 OHQ vol. 119, no. 1 and its documents, which are more familiar to readers and other legal histor
#     Year    : 2018.0
#     Score   : 0.917
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Thomas J. Connolly
# Abstract       : Amid the drumbeat of federal assimilation programs, the tribes persisted in reasserting control over
# Year           : 2016.0
# Exact Match    : False
# Avg. Score     : 0.920
# Duplicates:
#   - Title   : Toolstone Geography of the Pacific Northwest by Terry L. Ozbun and Ron L. Adams
#     Authors : Thomas J. Connolly
#     Abstract: Amid the drumbeat of federal assimilation programs, the tribes persisted in reasserting control over
#     Year    : 2016.0
#     Score   : 0.920
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : W. M. Hagen
# Abstract       : was upon his return from his Hajj that Malcolm broke from the Nation of Islam and founded Muslim Mos
# Year           : 2012.0
# Exact Match    : False
# Avg. Score     : 0.929
# Duplicates:
#   - Title   : The Tao of Travel: Enlightenments from Lives on the Road by Paul Theroux
#     Authors : W. M. Hagen
#     Abstract: was upon his return from his Hajj that Malcolm broke from the Nation of Islam and founded Muslim Mos
#     Year    : 2012.0
#     Score   : 0.929
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Parker Ts, Tommy S. Parker
# Abstract       : The benefits of trees, especially in urban settings, are often limited to discussions centered on en
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.935
# Duplicates:
#   - Title   : Trees and crime in urban areas: recommendations
#     Authors : Tommy S. Parker
#     Abstract: The benefits of trees, especially in urban settings, are often limited to discussions centered on en
#     Year    : 2018.0
#     Score   : 0.935
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Rachel S. Cordasco
# Abstract       : Vandana Singh Ambiguity Machines and Other Stories Easthampton, Massachusetts. Small Beer Press. 201
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.937
# Duplicates:
#   - Title   : Ambiguity Machines and Other Stories by Vandana Singh
#     Authors : Rachel S. Cordasco
#     Abstract: Vandana Singh Ambiguity Machines and Other Stories Easthampton, Massachusetts. Small Beer Press. 201
#     Year    : 2018.0
#     Score   : 0.937
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Elizaveta Barrett Ristroph
# Abstract       : Based on reviews of existing plans as well as interviews and conversations with 153 people that live
# Year           : 2017.0
# Exact Match    : False
# Avg. Score     : 0.938
# Duplicates:
#   - Title   : TOWARDS MORE COMMUNITY-ORIENTED AND COLLABORATIVE PLANNING FOR ALASKA NATIVE VILLAGES
#     Authors : Elizaveta Barrett Ristroph
#     Abstract: Based on reviews of existing plans as well as interviews and conversations with 153 people that live
#     Year    : 2018.0
#     Score   : 0.995
#   - Title   : Improving the quality of Alaska Native Village climate change planning
#     Authors : Barrett Ristroph Elizaveta
#     Abstract: Alaska Native Villages (ANVs) are trying to adapt to some of the most extreme climate change in the
#     Year    : 2018.0
#     Score   : 0.922
#   - Title   : Presenting a Picture of Alaska Native Village Adaptation: A Method of Analysis
#     Authors : Elizaveta Barrett Ristroph
#     Abstract: Alaska is a large state with 229 nationally recognized tribes, known as Alaska Native Villages (ANVs
#     Year    : 2017.0
#     Score   : 0.898
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : Subhas Chandra, Arnab Das
# Abstract       : The oldest habitat of the "Damodar-River-Based-Kanchannagar"; the Banka-Siphon-Dam (BSD) of Banka Ri
# Year           : 2023.0
# Exact Match    : False
# Avg. Score     : 0.942
# Duplicates:
#   - Title   : Banka-Siphon Attached Eden-Canal of Damodar May be Develop as ‘Biodiversity-Biomedicines-Hub’ Improv
#     Authors : Subhas Chandra Datta, Arnab Das
#     Abstract: The oldest habitat of the ‘Damodar-River-Based-Kanchannagar’; the Banka-Siphon-Dam (BSD) of Banka Ri
#     Year    : 2023.0
#     Score   : 0.942

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=False, require_authors=False)
# Out:
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Urban areas are increasingly experiencing the adverse effects of the urban heat island (UHI) phenome
# Year           : 2024.0
# Exact Match    : False
# Avg. Score     : 0.883
# Duplicates:
#   - Title   : Surface Urban Heat Island at High Spatio-Temporal Resolution
#     Authors : None
#     Abstract:
#     Year    : 2024.0
#     Score   : 0.886
#   - Title   : Assessing urban heat islands in southeast asia megacities: An integrated study of land use, climate
#     Authors : None
#     Abstract:
#     Year    : 2024.0
#     Score   : 0.880
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Adalberto Noyola, María Guadalupe Paredes, Juan Manuel Morgan-Sagastume and Leonor Patricia Güereca
# Year           : 2016.0
# Exact Match    : False
# Avg. Score     : 0.946
# Duplicates:
#   - Title   : Cover: Reduction of Greenhouse Gas Emissions From Municipal Wastewater Treatment in Mexico Based on
#     Authors : None
#     Abstract:
#     Year    : 2016.0
#     Score   : 0.946
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : The increase in temperature as consequence of the recent global warming has been reported to generat
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.987
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: The increase in temperature as consequence of the recent global warming has been reported to generat
#     Year    : 2018.0
#     Score   : 1.000
#   - Title   : Peer Review #1 of "Asymmetric responses to simulated global warming by populations of Colobanthus qu
#     Authors : None
#     Abstract: The increase in temperature as consequence of the recent global warming has been reported to generat
#     Year    : 2017.0
#     Score   : 0.974
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : The increase in temperature as consequence of the recent global warming has been reported to generat
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 0.987
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: The increase in temperature as consequence of the recent global warming has been reported to generat
#     Year    : 2018.0
#     Score   : 1.000
#   - Title   : Peer Review #1 of "Asymmetric responses to simulated global warming by populations of Colobanthus qu
#     Authors : None
#     Abstract: The increase in temperature as consequence of the recent global warming has been reported to generat
#     Year    : 2017.0
#     Score   : 0.974
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : On the cover: The cover image of an orange-breasted sunbird (Anthobaphes violacea) feeding on Erica
# Year           : 2016.0
# Exact Match    : False
# Avg. Score     : 0.990
# Duplicates:
#   - Title   : Cover
#     Authors : None
#     Abstract: On the cover: The cover image of an orange-breasted sunbird (Anthobaphes violacea) feeding on Erica
#     Year    : 2016.0
#     Score   : 0.990
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Geological correlations of East Antarctica with adjoining continents have been puzzling geologists e
# Year           : 2008.0
# Exact Match    : False
# Avg. Score     : 0.993
# Duplicates:
#   - Title   : About this title ‐ Geodynamic Evolution of East Antarctica: A Key to the East-West Gondwana Connecti
#     Authors : None
#     Abstract: Geological correlations of East Antarctica with adjoining continents have been puzzling geologists e
#     Year    : 2008.0
#     Score   : 0.993
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Ocean acidification, the ongoing decline of surface ocean pH and [CO32-] due to absorption of surplu
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Ocean acidification, the ongoing decline of surface ocean pH and [CO32-] due to absorption of surplu
#     Year    : 2018.0
#     Score   : 1.000
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Native bees contribute with a considerable portion of pollination services for endemic as well as ec
# Year           : 2018.0
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Native bees contribute with a considerable portion of pollination services for endemic as well as ec
#     Year    : 2018.0
#     Score   : 1.000

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=True, require_authors=True)
# Out:
# No duplicates found based on the specified NA conditions.

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=True, require_authors=False)
# Out:
# No duplicates found based on the specified NA conditions.

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=False, require_authors=True)
# Out:
# No duplicates found based on the specified NA conditions.

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=False, require_authors=False)
# Out:
# No duplicates found based on the specified NA conditions.

# %%
import pandas as pd
import math
import os

os.chdir(dir_path)

chunk_size = 20000
total_records = len(filtered_deduplicated_df)
num_chunks = math.ceil(total_records / chunk_size)

for i in range(num_chunks):
    start = i * chunk_size
    end = min((i + 1) * chunk_size, total_records)
    chunk = filtered_deduplicated_df.iloc[start:end]
    
    filename = f"data/OpenAlex/05_deduplicated/city_works_df_NA_abstr_added_dedup_{i+1}.parquet"
    chunk.to_parquet(filename)
    print(f"Saved {filename} with records {start} to {end-1}")
