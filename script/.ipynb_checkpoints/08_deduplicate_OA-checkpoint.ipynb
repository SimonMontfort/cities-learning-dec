# %%
import pandas as pd
import os 
import glob

dir_path = "/Users/simon/Documents/repo/cities-learning"

# Create the full search pattern
file_pattern = os.path.join(dir_path, "data/OpenAlex/city_works_df_NA_abstr_added*.feather")

# Find all matching files
files = glob.glob(file_pattern)

# Read all the files into a list of DataFrames
dfs = [pd.read_feather(file) for file in files]

# Optionally, concatenate them into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Optionally concatenate them into one DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# %%
pre_count = len(combined_df)
print("observations before exact deduplication:" +  str())
combined_df = combined_df.drop_duplicates(subset=["id"])
duplicates_dropped = pre_count-len(combined_df)
print("exact deduplicates dropped:" + str(duplicates_dropped))
print("observations after exact deduplication:" + str(len(combined_df)))
print("Observations with missing abstracts after exact deduplication: " + str(combined_df["abstract"].isna().sum()))
print("Observations with missing titles after exact deduplication: " + str(combined_df["title"].isna().sum()))
print("Observations with missing titles after exact deduplication: " + str(combined_df["authors"].isna().sum()))
print("Observations with missing titles after exact deduplication: " + str(combined_df["publication_year"].isna().sum()))
print(combined_df[combined_df["abstract"].isna()])
# Out:
# observations before exact deduplication:
# exact deduplicates dropped:676
# observations after exact deduplication:251124
# Observations with missing abstracts after exact deduplication: 11094
# Observations with missing titles after exact deduplication: 337
# Observations with missing titles after exact deduplication: 4878
# Observations with missing titles after exact deduplication: 0
#                                       id  \
# 8       https://openalex.org/W2796122528
# 24      https://openalex.org/W2411062836
# 45      https://openalex.org/W4286840151
# 87      https://openalex.org/W3201109727
# 184     https://openalex.org/W2473466218
# ...                                  ...
# 251604  https://openalex.org/W2611687965
# 251611  https://openalex.org/W3202014191
# 251613  https://openalex.org/W4312362558
# 251640  https://openalex.org/W4404214858
# 251736  https://openalex.org/W2785144348
#
#                                                     title abstract  \
# 8       Prikaz knjige Flexibility in adaptation planni...     None
# 24      A multifunctional green infrastructure design ...     None
# 45      Provisional Green Infrastructure in Indian Meg...     None
# 87      Natural-Historical Landscape Regeneration of U...     None
# 184     SPECIAL ISSUE &amp;ldquo; Trend of Stormwater ...     None
# ...                                                   ...      ...
# 251604  Water-Urban Land Use: Neglected Link in the Cl...     None
# 251611  VULNERABILITY AND ITS INFLUENCING FACTORS TO C...     None
# 251613  SYncronising EEA to CoM and other EU initiativ...     None
# 251640  Research-based Capacity Building for Advancing...     None
# 251736  Asset Planning for Climate Change Adaptation i...     None
#
#                                                   authors  publication_year  \
# 8                                          Ognjen Bonacci              2018
# 24                                         Cecilia Herzog              2016
# 45                                     Daniel R. Phillips              2022
# 87      Rafiee vida, vahidzadegan fariba, abdollahi ro...              2019
# 184                                            Yukio KIDA              2015
# ...                                                   ...               ...
# 251604                                       Hilda Blanco              2014
# 251611                   Agus Susatya, Anggraeni W Fettry              2019
# 251613                                               None              2018
# 251640                                               None              2024
# 251736                                      Alfredo Stein              2016
#
#         cited_by_count                                   cited_by_api_url  \
# 8                    0  https://api.openalex.org/works?filter=cites:W2...
# 24                   0  https://api.openalex.org/works?filter=cites:W2...
# 45                   0  https://api.openalex.org/works?filter=cites:W4...
# 87                   0  https://api.openalex.org/works?filter=cites:W3...
# 184                  0  https://api.openalex.org/works?filter=cites:W2...
# ...                ...                                                ...
# 251604               0  https://api.openalex.org/works?filter=cites:W2...
# 251611               0  https://api.openalex.org/works?filter=cites:W3...
# 251613               0  https://api.openalex.org/works?filter=cites:W4...
# 251640               0  https://api.openalex.org/works?filter=cites:W4...
# 251736               0  https://api.openalex.org/works?filter=cites:W2...
#
#                                          doi
# 8                                       None
# 24                                      None
# 45              https://doi.org/10.7302/4605
# 87                                      None
# 184     https://doi.org/10.7211/jjsrt.40.485
# ...                                      ...
# 251604                                  None
# 251611                                  None
# 251613        https://doi.org/10.3030/785033
# 251640      https://doi.org/10.30852/p.30555
# 251736                                  None
#
# [11094 rows x 8 columns]

# %%
from semhash import SemHash
import numpy as np

filtered_df = combined_df.copy()

cols_to_string = ["title", "authors", "abstract", "publication_year"]

for col in cols_to_string:
    filtered_df[col] = filtered_df[col].astype(str)

# Convert to list of dictionaries
records = filtered_df[["id", "title", "abstract", "authors", "publication_year"]].to_dict(orient="records")

# Now count missing values
missing_titles = sum(1 for rec in records if rec["title"] == "None")
missing_abstracts = sum(1 for rec in records if rec["abstract"] == "None")
missing_authors = sum(1 for rec in records if rec["authors"] == "None")
missing_pub_years = sum(1 for rec in records if rec["publication_year"] == "None")

print(f"Missing abstracts: {missing_abstracts}")
print(f"Missing titles: {missing_titles}")
print(f"Missing authors: {missing_authors}")
print(f"Missing publication years: {missing_pub_years}")
# Out:
# Missing abstracts: 11094
# Missing titles: 337
# Missing authors: 4878
# Missing publication years: 0

# %%
from sentence_transformers import SentenceTransformer

# Load multilingual model
# model = SentenceTransformer("paraphrase-multilingual-MiniLM-L12-v2")

# initialize SemHash with that model
semhash = SemHash.from_records(records=records, columns=["title", "abstract", "authors", "publication_year"], 
                               #model=model
                              )

threshold = 0.85
dedup_result = semhash.self_deduplicate(threshold=threshold)

# %%
# Create a class so that I can call attributes 
@dataclass
class DuplicateRecord:
    record: dict
    exact: bool
    duplicates: list
    
# A list to collect records with no valid duplicates
non_matching_records = []

# A new list to store filtered duplicates that meet the match criteria
filtered_duplicates = []

# Iterate through all duplicate records
for dup in dedup_result.duplicates:
    original = dup.record
    original_year = int(original.get("publication_year"))

    # List to hold valid matches for this original record
    valid_matches = []

    for rec, score in dup.duplicates:
        duplicate_year = int(rec.get("publication_year"))

        has_abstract = rec.get('abstract') and rec['abstract'].strip().lower() != "none"
        has_title = rec.get('title') and rec['title'].strip().lower() != "none"
        has_authors = rec.get('authors') and rec['authors'].strip().lower() != "none"
        
        close_years = abs(duplicate_year - original_year) <= 1
        match = False

        # Apply matching rules
        if close_years and has_abstract and has_authors and has_title and score > 0.85:
            match = True
        elif close_years and has_abstract and has_authors and not has_title and score > 0.88:
            match = True
        elif close_years and has_abstract and not has_authors and has_title and score > 0.92:
            match = True
        elif close_years and not has_abstract and has_authors and has_title and score > 0.90:
            match = True
        elif close_years and has_abstract and not has_title and has_authors and score > 0.90:
            match = True
        elif close_years and has_abstract and not has_title and not has_authors and score > 0.94:
            match = True
        elif close_years and not has_abstract and has_title and not has_authors and score > 0.97:
            match = True
        elif close_years and not has_abstract and not has_title and has_authors and score > 0.99:
            match = True
        elif close_years and not has_abstract and not has_authors and not has_title and score > 0.99:
            match = True

        if match:
            valid_matches.append((rec, score))

    # Store record only if it has valid matches
    if valid_matches:
        filtered_duplicates.append(
            DuplicateRecord(record=original, duplicates=valid_matches, exact=False)
        )
    else:
        non_matching_records.append(original)

# %%
# check that the numbers are right:
print(f"Duplicates based on more restrictive criteria with individual thresholds: {sum(1 for record in filtered_duplicates)}")
print(f"Number of duplicates that are likely falsely detected as such: {len(non_matching_records)}")
print(f"Restricted duplicates and those duplicates that do not belong to the restricted duplicates but had initially been predicted as such = {sum(1 for record in filtered_duplicates) + len(non_matching_records)} must be equal to the initial number of duplicates = {len(dedup_result.duplicates)}")
# Out:
# Duplicates based on more restrictive criteria with individual thresholds: 17384
# Number of duplicates that are likely falsely detected as such: 1775
# Restricted duplicates and those duplicates that do not belong to the restricted duplicates but had initially been predicted as such = 19159 must be equal to the initial number of duplicates = 19159

# %%
# add false positive duplicates to the deduplicated list
filtered_deduplicated = dedup_result.deduplicated.copy()
filtered_deduplicated.extend(non_matching_records)

# %%
## transform to dfs 
# SemHash: duplicates and the deduplicated records from the semhashing as dataframes
deduplicated_hash_df = pd.DataFrame(dedup_result.deduplicated)
dup_records = [dup.record for dup in dedup_result.duplicates]
duplicates_hash_df = pd.DataFrame(dup_records)
# customized additional filtering:
filtered_duplicates_df = pd.DataFrame(filtered_duplicates)
filtered_deduplicated_df = pd.DataFrame(filtered_deduplicated)

# %%
print(total_records)
print(total_records)
# Out:
# {'id': 'https://openalex.org/W4244269897', 'title': 'Fig. 5. Map displaying the slope (colour scale) and adjusted R2 (size scale) for the linear regression of green infrastructure variables on per capita income. A separate linear model was performed for each municipal district (see Fig. 1), and points reflect the municipality centroids. The reader can interpret these values as the slope and fit of the linear trend lines plotted in Fig. 3 except here they are stratified by district municipality and not race.', 'abstract': 'Urban green infrastructure provides ecosystem services that are essential to human wellbeing. A dearth of national-scale assessments in the Global South has precluded the ability to explore how political regimes, such as the forced racial segregation in South Africa during and after Apartheid, have influenced the extent of and access to green infrastructure over time. We investigate whether there are disparities in green infrastructure distributions across race and income geographies in urban South Africa. Using open-source satellite imagery and geographic information, along with national census statistics, we find that public and private green infrastructure is more abundant, accessible, greener and more treed in high-income relative to low-income areas, and in areas where previously advantaged racial groups (i.e. White citizens) reside.', 'authors': 'Zander S. Venter, Charlie M. Shackleton, Francini Van Staden, Odirile Sebogoe, Vanessa A Masterson', 'publication_year': '2021'}
# 360788

# %%
# remove all those ids that are insided 
print("----------SemHash numbers-------------------------------------------------------------------------")
print(f"SemHash deduplicated: {len(deduplicated_hash_df)}")
print(f"SemHash duplicates: {len(duplicates_hash_df)}")
print("----------Restricted filtering numbers------------------------------------------------------------")
print(f"Restricted deduplicated: {len(filtered_duplicates)}")
print(f"Restricted duplicates: {len(filtered_deduplicated)}")
print("----------Additional------------------------------------------------------------------------------")
print(f"SemHash duplicates that are no duplicates according to restricted criteria: {len(duplicates_hash_df)- len(filtered_duplicates)}")
print(f"All wrongly assigned SemHash duplicates are correctly reasssigned: {len(filtered_deduplicated)-len(deduplicated_hash_df) == len(duplicates_hash_df) - len(filtered_duplicates)}")
print(f"Final percentage of removed: {(len(filtered_duplicates_df)/ (len(deduplicated_hash_df) + len(duplicates_hash_df))):.2%}")
# Out:
# ----------SemHash numbers-------------------------------------------------------------------------
# SemHash deduplicated: 231965
# SemHash duplicates: 19159
# ----------Restricted filtering numbers------------------------------------------------------------
# Restricted deduplicated: 17384
# Restricted duplicates: 233740
# ----------Additional------------------------------------------------------------------------------
# SemHash duplicates that are no duplicates according to restricted criteria: 1775
# All wrongly assigned SemHash duplicates are correctly reasssigned: True
# Final percentage of removed: 6.92%

# %%
def filter_duplicates_by_na_fields(duplicates, require_abstract=True, require_title=True, require_authors=True):
    """
    Filters and prints the 10 duplicate groups with the lowest average score,
    where the original record meets the specified NA conditions.
    
    Args:
        duplicates (list): List of DuplicateRecord objects.
        require_abstract (bool): If True, abstract must NOT be NA.
        require_title (bool): If True, title must NOT be NA.
        require_authors (bool): If True, authors must NOT be NA.
    """
    if not duplicates:
        print("No duplicates to check.")
        return

    filtered = []

    for dup in duplicates:
        has_abstract = dup.record.get('abstract') and dup.record['abstract'].strip().lower() != "none"
        has_title = dup.record.get('title') and dup.record['title'].strip().lower() != "none"
        has_authors = dup.record.get('authors') and dup.record['authors'].strip().lower() != "none"

        condition = (has_abstract == require_abstract) and (has_title == require_title) and (has_authors == require_authors)

        if condition and dup.duplicates:
            avg_score = sum(score for _, score in dup.duplicates) / len(dup.duplicates)
            filtered.append((avg_score, dup))

    if not filtered:
        print("\nNo duplicates found based on the specified NA conditions.")
        return

    # Sort by average score and take the 10 lowest
    filtered.sort(key=lambda x: x[0])
    filtered = filtered[:10]

    for avg_score, dup in filtered:
        print("\n=== DUPLICATE RECORD ===")
        print(f"Original Title : {dup.record.get('title', '')[:100]}")
        print(f"Authors        : {dup.record.get('authors', '')[:100]}")
        print(f"Abstract       : {dup.record.get('abstract', '')[:100]}")
        print(f"Year           : {str(dup.record.get('publication_year', ''))[:100]}")
        print(f"Exact Match    : {dup.exact}")
        print(f"Avg. Score     : {avg_score:.3f}")
        print("Duplicates:")
        for rec, score in dup.duplicates:
            print(f"  - Title   : {rec.get('title', '')[:100]}")
            print(f"    Authors : {rec.get('authors', '')[:100]}")
            print(f"    Abstract: {rec.get('abstract', '')[:100]}")
            print(f"    Year    : {str(rec.get('publication_year', ''))[:100]}")
            print(f"    Score   : {score:.3f}")

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=True, require_authors=True)
# Out:
# === DUPLICATE RECORD ===
# Original Title : Temperature of Paved Streets in Urban Mockups and Its Implication of Reflective Cool Pavements
# Authors        : Yi Zhang, Peiyuan Wei, Lei Wang, Yinghong Qin
# Abstract       : In summer, urban heat islands increase building cooling demands, aggravate air pollution, and cause
# Year           : 2021
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : Experimental Study on the Thermal Characteristics of Urban Mockups With Different Paved Streets
#     Authors : Yinghong Qin, Peiyuan Wei, Junsong Wang, Kanghao Tan
#     Abstract: Abstract Pavements in urban area absorb more sunlight due to the canyon-like geomorphology of the ur
#     Year    : 2021
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : Enhancing Sustainable Urban Design and Development Through Data-Driven Approaches and Interpretable
# Authors        : Nasim Eslamirad, Mahdi Rasoulinezhad, Francesco De Luca, Sadok Ben Yahia, Kimmo Lylykangas
# Abstract       : With the ongoing urbanization, cities face increasing environmental challenges impacting human well-
# Year           : 2023
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : From near real-time urban data to an explainable city-scale model to help reduce the Urban Heat Isla
#     Authors : Nasim Eslamirad, Francesco De Luca, Sadok Ben Yahia, Kimmo Lylykangas
#     Abstract: Abstract Urbanization is associated with increasing the temperature of urban areas and phenomena lik
#     Year    : 2023
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : Climate Change and Cities
# Authors        : Sara Hughes
# Abstract       : Cities are playing an increasingly important role in addressing climate change, adopting increasingl
# Year           : 2020
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : Principles, drivers, and policy tools for just climate change adaptation in legacy cities
#     Authors : Sara Hughes
#     Abstract: Climate change adaptation presents an opportunity for legacy cities to address growing social, racia
#     Year    : 2020
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : 황사현상의 장래변화 예측에 관한 기초 연구
# Authors        : 황의현, 김창환, 최재익
# Abstract       : In this study, future status changes of Asian dust were investigated by the analysis of the change o
# Year           : 2009
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : 수직 공간 내에서 고도변화에 따른 기압차로 인한 기류현상 예측에 관한 연구
#     Authors : 정광섭, 김철호
#     Abstract: On 21st century, global warming is the most serious environmental problem threatening the existence
#     Year    : 2009
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : Urban Canopy Air Temperature Variations in the Grey and Green Spaces of a Heat Island
# Authors        : James Parker, Martin Fletcher, Felix Thomas, Mohammad Taleghani
# Abstract       : Urban green spaces are acknowledged as a vital component in a healthy city, providing a wealth of be
# Year           : 2023
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : Characteristics of air temperature and thermal comfort in the grey and green spaces of an urban heat
#     Authors : James Parker, Martin Fletcher, Felix Thomas
#     Abstract: Urban green spaces are acknowledged as a vital component in a healthy city, providing a wealth of be
#     Year    : 2024
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : 서울시 도시 숲의 경관생태와 관리방안
# Authors        : Woo-Seok Kong, 김건옥, Sle-gee Lee, 박희나
# Abstract       : This work aims to establish the landscape ecological countermeasures to improve the sustainability o
# Year           : 2014
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : 기후변화 적응을 위한 도시계획 방안 연구
#     Authors : 이성희, 김정곤
#     Abstract: This study aims to understand abnormal climate caused by impacts of climate change and to suggest th
#     Year    : 2014
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : On the Impact of GNSS Multipath Correction Maps on Slant Wet Delays for Tracking Severe Weather Even
# Authors        : Felix Norman Teferle, Addisu Hunegnaw, Hüseyin Duman, Hakki Baltaci, Yohannes Getachew Ejigu, Jan Do
# Abstract       : &amp;lt;p&amp;gt;Climate change has led to an increase in the frequency and severity of weather even
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : Analysis of GNSS sensed slant wet delay during the severe weather events in central Europe
#     Authors : Addisu Hunegnaw, Hüseyin Duman, Gunnar Elgered, Jan Douša, Felix Norman Teferle
#     Abstract: &amp;lt;p&amp;gt;&amp;lt;strong&amp;gt;Over the last few decades, anthropogenic greenhouse gas emiss
#     Year    : 2022
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : Estimating Carbon Emissions of Northeast Brazil Railway System
# Authors        : Diogo Da Fonseca-Soares, Sayonara Andrade Eliziário, Josiclêda Domiciano Galvíncio, Ángel Ramos-Rida
# Abstract       : This article addresses the developing of a framework to obtain specific GHG emissions for the railwa
# Year           : 2024
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : Greenhouse Gas Emissions in Railways: Systematic Review of Research Progress
#     Authors : Diogo Da Fonseca-Soares, Sayonara Andrade Eliziário, Josiclêda Domiciano Galvíncio, Ángel Ramos-Rida
#     Abstract: Rail transportation plays a crucial role in reducing carbon emissions from the transportation system
#     Year    : 2024
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : Quantify the Effect of China’s Emission Trading Scheme on Low-carbon Eco-efficiency: Evidence from C
# Authors        : Miaomiao Tao, Pierre Failler, Lim Thye Goh, Wee‐Yeap Lau, Hanghang Dong, Liang Xie
# Abstract       : Abstract The establishment of a carbon trading market is crucial for China to fulfil its carbon emis
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : Effects of Carbon Trading Pilot on Carbon Emission Reduction: Evidence from China’s 283 Prefecture-L
#     Authors : Miaomiao Tao, Lim Thye Goh
#     Abstract: Empirical evidence demonstrates that market-driven carbon trading scheme (ETS) is a crucial instrume
#     Year    : 2022
#     Score   : 0.850
#
# === DUPLICATE RECORD ===
# Original Title : ОСОБЕННОСТИ ФУНКЦИОНАЛЬНЫХ ВОЗМОЖНОСТЕЙ СЕРДЕЧНО-СОСУДИСТОЙ СИСТЕМЫ СТУДЕНТОВ ВУЗА, ПРОЖИВАЮЩИХ В ПР
# Authors        : Ольга Юрьевна Катульская
# Abstract       : The aim of this work was to evaluate the adaptive capacity of a technical college student living in
# Year           : 2013
# Exact Match    : False
# Avg. Score     : 0.850
# Duplicates:
#   - Title   : Влияние эколого-гигиенических факторов на распространенность болезней системы кровообращения у насел
#     Authors : П. Ф. Кику, Татьяна Владимировна Горборукова, Татьяна Александровна Гвозденко
#     Abstract: The article presents the results of the environmental and hygienic assessment of the prevalence of d
#     Year    : 2013
#     Score   : 0.850

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=True, require_authors=False)
# Out:
# === DUPLICATE RECORD ===
# Original Title : Preface
# Authors        : None
# Abstract       : Organized by Beijing Jiaotong University (Beijing, China), the 2021 2nd International Symposium on W
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.921
# Duplicates:
#   - Title   : Preface
#     Authors : None
#     Abstract: 3 rd International Conference on Environmental Design (ICED2022) is focused on the most recent scien
#     Year    : 2022
#     Score   : 0.921
#
# === DUPLICATE RECORD ===
# Original Title : Probability distributions for changes in regional employment shares of manufacturing
# Authors        : None
# Abstract       : Manufacturing, a cornerstone of economic growth and development, has undergone profound changes in r
# Year           : 2023
# Exact Match    : False
# Avg. Score     : 0.921
# Duplicates:
#   - Title   : Distribution of manufacturing employment in TL3 regions, 2018
#     Authors : None
#     Abstract: Manufacturing, a cornerstone of economic growth and development, has undergone profound changes in r
#     Year    : 2023
#     Score   : 0.921
#
# === DUPLICATE RECORD ===
# Original Title : Preface
# Authors        : None
# Abstract       : The last few decades in human history have been characterised by unprecedented activity in scientifi
# Year           : 2021
# Exact Match    : False
# Avg. Score     : 0.921
# Duplicates:
#   - Title   : Preface
#     Authors : None
#     Abstract: It is a great honor for us, Faculty of Forestry of Hasanuddin University, to host the 2 nd Biennial
#     Year    : 2021
#     Score   : 0.921
#
# === DUPLICATE RECORD ===
# Original Title : Preface
# Authors        : None
# Abstract       : Sustainable tourism has never been more important, particularly in Africa.We are living in unprecede
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.921
# Duplicates:
#   - Title   : Preface
#     Authors : None
#     Abstract: Welcome to the sbe22 Berlin D-A-CH conference The sbe22 Berlin D-A-CH conference, which will take pl
#     Year    : 2022
#     Score   : 0.921
#
# === DUPLICATE RECORD ===
# Original Title : Preface
# Authors        : None
# Abstract       : A changing climate, a growing population, increasing demand for food and energy, expanding urban are
# Year           : 2019
# Exact Match    : False
# Avg. Score     : 0.921
# Duplicates:
#   - Title   : Preface
#     Authors : None
#     Abstract: Ensuring long-term water security is essential in the pathway towards climate change adaptation, inc
#     Year    : 2019
#     Score   : 0.921
#
# === DUPLICATE RECORD ===
# Original Title : Preface
# Authors        : None
# Abstract       : Ensuring long-term water security is essential in the pathway towards climate change adaptation, inc
# Year           : 2019
# Exact Match    : False
# Avg. Score     : 0.921
# Duplicates:
#   - Title   : Preface
#     Authors : None
#     Abstract: A changing climate, a growing population, increasing demand for food and energy, expanding urban are
#     Year    : 2019
#     Score   : 0.921
#
# === DUPLICATE RECORD ===
# Original Title : Executive Summary
# Authors        : None
# Abstract       : Water-related investments deliver substantial benefits for water security and sustainable developmen
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.921
# Duplicates:
#   - Title   : Executive summary
#     Authors : None
#     Abstract: Intermediary cities provide an unprecedented opportunity for advancing with climate mitigation and a
#     Year    : 2022
#     Score   : 0.921
#
# === DUPLICATE RECORD ===
# Original Title : Executive summary
# Authors        : None
# Abstract       : The 17 Sustainable Development Goals adopted in 2015 by the United Nations set the global agenda for
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 0.922
# Duplicates:
#   - Title   : Executive summary
#     Authors : None
#     Abstract: The world needs more and better infrastructure. Demand for infrastructure investment has risen and i
#     Year    : 2018
#     Score   : 0.922
#
# === DUPLICATE RECORD ===
# Original Title : Table_1.xlsx
# Authors        : None
# Abstract       : The middle Miocene Climate Optimum (MMCO) was the warmest interval of the last 23 million years and
# Year           : 2021
# Exact Match    : False
# Avg. Score     : 0.922
# Duplicates:
#   - Title   : Table_1.XLSX
#     Authors : None
#     Abstract: The intensive use of wood resources is a challenging subject due to urbanization, population growth,
#     Year    : 2021
#     Score   : 0.922
#
# === DUPLICATE RECORD ===
# Original Title : New Books
# Authors        : None
# Abstract       : AcousticsSection:ChooseTop of pageAcoustics <<Astronomy and astrophysic...Atomic and molecular phys.
# Year           : 2003
# Exact Match    : False
# Avg. Score     : 0.922
# Duplicates:
#   - Title   : New Books
#     Authors : None
#     Abstract: Astronomy and astrophysics Section:ChooseTop of pageAstronomy and astrophysic... <<Atomic and molecu
#     Year    : 2003
#     Score   : 0.922

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=False, require_authors=True)
# Out:
# No duplicates found based on the specified NA conditions.

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=True, require_title=False, require_authors=False)
# Out:
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : ASEAN is regarded as an economically dynamic region with notable policies towards economic openness,
# Year           : 2019
# Exact Match    : False
# Avg. Score     : 0.943
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: This study examines the impacts of crucial factors associated with Vietnam's socio-economic developm
#     Year    : 2018
#     Score   : 0.943
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : This study examines the impacts of crucial factors associated with Vietnam's socio-economic developm
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 0.943
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: ASEAN is regarded as an economically dynamic region with notable policies towards economic openness,
#     Year    : 2019
#     Score   : 0.943
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Collection of selected, peer reviewed papers from the 2013 International Conference on Renewable Ene
# Year           : 2013
# Exact Match    : False
# Avg. Score     : 0.954
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Collection of selected, peer reviewed papers from the 2013 2nd International Conference on Energy an
#     Year    : 2013
#     Score   : 0.954
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Collection of selected, peer reviewed papers from the 3rd International Conference on Energy, Enviro
# Year           : 2013
# Exact Match    : False
# Avg. Score     : 0.962
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Collection of selected, peer reviewed papers from the 2013 2nd International Conference on Energy an
#     Year    : 2013
#     Score   : 0.962
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Native bees contribute with a considerable portion of pollination services for endemic as well as ec
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Native bees contribute with a considerable portion of pollination services for endemic as well as ec
#     Year    : 2018
#     Score   : 1.000
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Native bees contribute with a considerable portion of pollination services for endemic as well as ec
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Native bees contribute with a considerable portion of pollination services for endemic as well as ec
#     Year    : 2018
#     Score   : 1.000
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Ocean acidification, the ongoing decline of surface ocean pH and [CO32-] due to absorption of surplu
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Ocean acidification, the ongoing decline of surface ocean pH and [CO32-] due to absorption of surplu
#     Year    : 2018
#     Score   : 1.000
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : Ocean acidification, the ongoing decline of surface ocean pH and [CO32-] due to absorption of surplu
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: Ocean acidification, the ongoing decline of surface ocean pH and [CO32-] due to absorption of surplu
#     Year    : 2018
#     Score   : 1.000
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : The increase in temperature as consequence of the recent global warming has been reported to generat
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: The increase in temperature as consequence of the recent global warming has been reported to generat
#     Year    : 2018
#     Score   : 1.000
#
# === DUPLICATE RECORD ===
# Original Title : None
# Authors        : None
# Abstract       : The increase in temperature as consequence of the recent global warming has been reported to generat
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 1.000
# Duplicates:
#   - Title   : None
#     Authors : None
#     Abstract: The increase in temperature as consequence of the recent global warming has been reported to generat
#     Year    : 2018
#     Score   : 1.000

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=True, require_authors=True)
# Out:
# === DUPLICATE RECORD ===
# Original Title : Spatial Effects and Influencing Factors of Urban Carbon Emissions in the Yangtze River Economic Belt
# Authors        : 欣玥 庞
# Abstract       : None
# Year           : 2023
# Exact Match    : False
# Avg. Score     : 0.900
# Duplicates:
#   - Title   : Analysis of the Spatial and Temporal Distribution of Carbon Footprints and Influencing Factors in Sm
#     Authors : 兰 陈
#     Abstract: None
#     Year    : 2023
#     Score   : 0.900
#
# === DUPLICATE RECORD ===
# Original Title : To Opt-in or to Cop Out: COP26 and the Policy Dynamics of Decarbonising African Cities
# Authors        : Ayodele Asekomeh, Obindah Gershon, Smith I. Azubuike
# Abstract       : None
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : Introduction: Decarbonising African Cities in a Carbon-Constrained World
#     Authors : Smith I. Azubuike, Obindah Gershon, Ayodele Asekomeh
#     Abstract: None
#     Year    : 2022
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : Evidence of Long-term Climate Change at Major Cities of India during the Twentieth Century
# Authors        : Anargha Dhorde, Anargha Wakhare
# Abstract       : None
# Year           : 2009
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : Detection and understanding of climatic response to urbanization over major cities of India
#     Authors : Anargha Dhorde, Anargha Wakhare
#     Abstract: None
#     Year    : 2009
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : Green and Blue Infrastructure in Cities
# Authors        : Katia Perini
# Abstract       : None
# Year           : 2016
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : Green infrastructure in New York City: top down and bottom up initiatives to improve environmental q
#     Authors : Katia Perini
#     Abstract: None
#     Year    : 2016
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : Introduction: Climate Change and Cities—Perspectives, Planning and People
# Authors        : Ali Cheshmehzangi, Ayotunde Dawodu
# Abstract       : None
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : Sustainable Urban Development in the Age of Climate Change
#     Authors : Ali Cheshmehzangi, Ayotunde Dawodu
#     Abstract: None
#     Year    : 2018
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : A Study on City Greenhouse Gas Emissions Inventory
# Authors        : Bofeng Cai
# Abstract       : None
# Year           : 2011
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : Research on Greenhouse Gas Emissions Inventory in the Cities of China
#     Authors : Bofeng Cai
#     Abstract: None
#     Year    : 2012
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : Assessing Impacts of Climate Change and Climate Migration on Urban Infrastructure Resilience
# Authors        : Alexandra Maxim, Emily Grubert
# Abstract       : None
# Year           : 2020
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : Author response for "Effects of climate migration on town-to-city transitions in the United States:
#     Authors : Alexandra Maxim, Emily Grubert
#     Abstract: None
#     Year    : 2021
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : The Construction of Cosmopolitanized News of Climate Change at the Micro-scale: Representation, Prod
# Authors        : Ingrid Volkmer, Kasim Sharif
# Abstract       : None
# Year           : 2018
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : Cosmopolitanized Scales of Climate Change Communication: Arenas, Actors and Communicative Spaces
#     Authors : Ingrid Volkmer, Kasim Sharif
#     Abstract: None
#     Year    : 2018
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : 40444 Investigation for mitigating Urban Heat Island in Osaka (part 2) : Evaluation of land and sea
# Authors        : Hiroshi Miyazaki, Asa Takao, Yasushi Kimura, Hiroki Maeda, Kosuke Kittaka, Kosuke Ido, Koki Izumi
# Abstract       : None
# Year           : 2010
# Exact Match    : False
# Avg. Score     : 0.901
# Duplicates:
#   - Title   : 40446 Investigation for mitigating Urban Heat Island in Osaka (part 5) : Blooming of Prunus x yedoen
#     Authors : Hiroki Maeda, Hiroshi Miyazaki, Koki Izumi, Yasushi Kimura, Kosuke Ido, Asa Takao, Kosuke Kittaka, 真
#     Abstract: None
#     Year    : 2010
#     Score   : 0.901
#
# === DUPLICATE RECORD ===
# Original Title : Urban Renewal [Book Review] Resilient Cities: Responding to Peak Oil and Climate Change
# Authors        : Don Alexander
# Abstract       : None
# Year           : 2010
# Exact Match    : False
# Avg. Score     : 0.902
# Duplicates:
#   - Title   : [Book Review] Resilient Cities: Responding to Peak Oil and Climate Change & Cities as Sustainable Ec
#     Authors : Don Alexander
#     Abstract: None
#     Year    : 2009
#     Score   : 0.902

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=True, require_authors=False)
# Out:
# === DUPLICATE RECORD ===
# Original Title : Climate-Resilient City
# Authors        : None
# Abstract       : None
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.973
# Duplicates:
#   - Title   : Urban Climate Resilience
#     Authors : None
#     Abstract: None
#     Year    : 2022
#     Score   : 0.973
#
# === DUPLICATE RECORD ===
# Original Title : Urban Climate Resilience
# Authors        : None
# Abstract       : None
# Year           : 2022
# Exact Match    : False
# Avg. Score     : 0.973
# Duplicates:
#   - Title   : Climate-Resilient City
#     Authors : None
#     Abstract: None
#     Year    : 2022
#     Score   : 0.973
#
# === DUPLICATE RECORD ===
# Original Title : CO2 emissions from urban transport by mode and scenario
# Authors        : None
# Abstract       : None
# Year           : 2019
# Exact Match    : False
# Avg. Score     : 0.973
# Duplicates:
#   - Title   : CO2 emissions from domestic non-urban passenger transport by mode and scenario
#     Authors : None
#     Abstract: None
#     Year    : 2019
#     Score   : 0.974
#   - Title   : CO2 emissions from urban passenger transport by scenario
#     Authors : None
#     Abstract: None
#     Year    : 2019
#     Score   : 0.973
#
# === DUPLICATE RECORD ===
# Original Title : CO2 emissions from urban passenger transport by scenario
# Authors        : None
# Abstract       : None
# Year           : 2019
# Exact Match    : False
# Avg. Score     : 0.974
# Duplicates:
#   - Title   : CO2 emissions from domestic non-urban passenger transport by mode and scenario
#     Authors : None
#     Abstract: None
#     Year    : 2019
#     Score   : 0.975
#   - Title   : CO2 emissions from urban transport by mode and scenario
#     Authors : None
#     Abstract: None
#     Year    : 2019
#     Score   : 0.973
#
# === DUPLICATE RECORD ===
# Original Title : CO2 emissions from domestic non-urban passenger transport by mode and scenario
# Authors        : None
# Abstract       : None
# Year           : 2019
# Exact Match    : False
# Avg. Score     : 0.974
# Duplicates:
#   - Title   : CO2 emissions from urban passenger transport by scenario
#     Authors : None
#     Abstract: None
#     Year    : 2019
#     Score   : 0.975
#   - Title   : CO2 emissions from urban transport by mode and scenario
#     Authors : None
#     Abstract: None
#     Year    : 2019
#     Score   : 0.974
#
# === DUPLICATE RECORD ===
# Original Title : CO2 emissions per capita of urban passenger transport in 2015
# Authors        : None
# Abstract       : None
# Year           : 2021
# Exact Match    : False
# Avg. Score     : 0.975
# Duplicates:
#   - Title   : Per capita CO2 emissions from urban passenger transport by world region in 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.975
#
# === DUPLICATE RECORD ===
# Original Title : CO2 emissions from urban passenger transport by mode to 2050
# Authors        : None
# Abstract       : None
# Year           : 2021
# Exact Match    : False
# Avg. Score     : 0.975
# Duplicates:
#   - Title   : CO2 emissions from urban passenger transport by world region in 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.980
#   - Title   : CO2 emissions from non-urban passenger transport by world region to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.976
#   - Title   : CO2 emissions for urban passenger, non-urban passenger and freight transport to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.975
#   - Title   : CO2 emissions from non-urban passenger transport by sub-sector to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.973
#   - Title   : Per capita CO2 emissions from urban passenger transport by world region in 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.970
#
# === DUPLICATE RECORD ===
# Original Title : CO2 emissions from non-urban passenger transport by sub-sector to 2050
# Authors        : None
# Abstract       : None
# Year           : 2021
# Exact Match    : False
# Avg. Score     : 0.976
# Duplicates:
#   - Title   : CO2 emissions from non-urban passenger transport by world region to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.980
#   - Title   : CO2 emissions for urban passenger, non-urban passenger and freight transport to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.976
#   - Title   : CO2 emissions from urban passenger transport by world region in 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.975
#   - Title   : CO2 emissions from urban passenger transport by mode to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.973
#
# === DUPLICATE RECORD ===
# Original Title : CO2 emissions for urban passenger, non-urban passenger and freight transport to 2050
# Authors        : None
# Abstract       : None
# Year           : 2021
# Exact Match    : False
# Avg. Score     : 0.976
# Duplicates:
#   - Title   : CO2 emissions from non-urban passenger transport by world region to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.977
#   - Title   : CO2 emissions from urban passenger transport by world region in 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.976
#   - Title   : CO2 emissions from non-urban passenger transport by sub-sector to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.976
#   - Title   : CO2 emissions from urban passenger transport by mode to 2050
#     Authors : None
#     Abstract: None
#     Year    : 2021
#     Score   : 0.975
#
# === DUPLICATE RECORD ===
# Original Title : Density Category 5 (1.2 – 1.5): Urban Apartments in Green Areas 3: Courtyard and Garden
# Authors        : None
# Abstract       : None
# Year           : 2014
# Exact Match    : False
# Avg. Score     : 0.979
# Duplicates:
#   - Title   : Density Category 4 (0.9 – 1.2): Urban Apartments in Green Areas 2: Row and Courtyard
#     Authors : None
#     Abstract: None
#     Year    : 2014
#     Score   : 0.979

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=False, require_authors=True)
# Out:
# No duplicates found based on the specified NA conditions.

# %%
filter_duplicates_by_na_fields(filtered_duplicates, require_abstract=False, require_title=False, require_authors=False)
# Out:
# No duplicates found based on the specified NA conditions.

# %%
import pandas as pd
import math
import os

os.chdir(dir_path)

chunk_size = 20000
total_records = len(filtered_deduplicated_df)
num_chunks = math.ceil(total_records / chunk_size)

for i in range(num_chunks):
    start = i * chunk_size
    end = min((i + 1) * chunk_size, total_records)
    chunk = filtered_deduplicated_df.iloc[start:end]
    
    filename = f"data/OpenAlex/04_deduplicated/city_works_df_NA_abstr_added_dedup_{i+1}.parquet"
    chunk.to_parquet(filename)
    print(f"Saved {filename} with records {start} to {end-1}")
# Out:
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_1.parquet with records 0 to 19999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_2.parquet with records 20000 to 39999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_3.parquet with records 40000 to 59999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_4.parquet with records 60000 to 79999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_5.parquet with records 80000 to 99999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_6.parquet with records 100000 to 119999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_7.parquet with records 120000 to 139999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_8.parquet with records 140000 to 159999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_9.parquet with records 160000 to 179999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_10.parquet with records 180000 to 199999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_11.parquet with records 200000 to 219999
# Saved data/OpenAlex/deduplicated_and_translated/city_works_df_NA_abstr_added_dedup_12.parquet with records 220000 to 233739
