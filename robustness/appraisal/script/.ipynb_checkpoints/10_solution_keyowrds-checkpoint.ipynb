# %%
import os
import glob
import pandas as pd
import re
from whoosh import index
from whoosh.fields import Schema, TEXT, ID
from whoosh.qparser import QueryParser, OrGroup
from whoosh import query as Q

# -----------------------------
# 1. Set working directory
# -----------------------------
os.chdir("/Users/simon/Documents/repo/cities-learning-dec/robustness/appraisal")

# -----------------------------
# 2. Read first OA CSV for testing
# -----------------------------
file_pattern = "/Users/simon/Documents/repo/cities-learning/data/OpenAlex/05_deduplicated/city_works_df_NA_abstr_added_dedup_*.csv"
file_names = glob.glob(file_pattern)

all_oas = [pd.read_csv(f) for f in file_names]
oa = pd.concat(all_oas, ignore_index=True)

# Make sure abstract column exists
assert 'abstract' in oa.columns, "Column 'abstract' not found"

# -----------------------------
# 3. Read climate solution typology
# -----------------------------
typology_file = "./data/climate_solutions_typology/climate_solution_typology_long.xlsx"
typology = pd.read_excel(typology_file)
typology['solution_name'] = typology['solution_name'].str.strip()
assert 'search_string' in typology.columns, "Column 'search_string' not found"

# -----------------------------
# 4. Split abstracts into sentences
# -----------------------------
import spacy

# Load the pretrained English model (small model is enough for sentence splitting)
nlp = spacy.load("en_core_web_sm")

sentences = []
sentence_id = []
id = []

for i, abstract in oa['abstract'].items():
    if pd.isna(abstract):
        continue
    
    doc = nlp(str(abstract))
    for j, sent in enumerate(doc.sents, start=1):
        oa_id = oa.at[i, 'id']
        id.append(oa_id)  
        sentences.append(sent.text.strip())
        sentence_id.append(f"{oa_id}_s{j}")
        

# Create a DataFrame for sentences
sent_df = pd.DataFrame({
    'sentence_id': sentence_id,
    'id': id,
    'sentence': sentences
})


# -----------------------------
# 5. Create Whoosh index for sentences
# -----------------------------
schema = Schema(id=ID(stored=True), sentence=TEXT(stored=True))
if not os.path.exists("data/climate_solutions_typology/indexdir_sent"):
    os.mkdir("data/climate_solutions_typology/indexdir_sent")
ix_sent = index.create_in("data/climate_solutions_typology/indexdir_sent", schema)

writer = ix_sent.writer()
for i, row in sent_df.iterrows():
    writer.add_document(id=str(row['sentence_id']), sentence=row['sentence'])
writer.commit()

# -----------------------------
# 6. Search sentences for each climate solution
# -----------------------------
results_sent = {}

for idx, row in typology.iterrows():
    solution_name = row['solution_name']
    solution_id = row['solution_id']
    search_string = row['search_string']

    print(f"Searching for solution: {solution_name}")

    with ix_sent.searcher() as searcher:
        # exact phrases using Phrase class (slop=0)
        qp = QueryParser("sentence", schema=ix_sent.schema, group=OrGroup.factory(0), phraseclass=Q.Phrase)
        q = qp.parse(search_string)
        hits = searcher.search(q, limit=None)
        match_ids = set(hit['id'] for hit in hits)

        # Create a boolean column for matches
        sent_df[f'solution_{solution_id}_match'] = sent_df['sentence_id'].isin(match_ids)

# -----------------------------
# 7. Inspect results
# -----------------------------
print(sent_df.head(20))

# -----------------------------
# 7. Check results in more detail for a few solutions
# -----------------------------
def print_matching_abstracts_from_typology(oa_df, typology_df, solution_id, column="abstract", n=5):
    # solution_name_clean = solution_name.strip()  # remove trailing spaces from input
    match_col = f"solution_{solution_id}_match"
    print(f"Looking for match column: {match_col}")
    solution_name = typology_df[typology_df["solution_id"] == solution_id]["solution_name"]
    print(solution_name)

    # Strip spaces in typology when matching
    search_row = typology_df.loc[typology_df['solution_id'] == solution_id]

    if search_row.empty:
        print(f"No search string found for solution '{solution_id}'")
        return
    search_string = search_row['search_string'].values[0]

    if match_col not in oa_df.columns:
        print(f"No match column found for solution '{solution_id}'")
        return

    matched_abstracts = oa_df.loc[oa_df[match_col], column]

    if matched_abstracts.empty:
        print(f"No abstracts matched for solution '{solution_id}'")
        return

    print(f"\n--- Sample abstracts matching '{solution_name}' ---")
    print(f"Search query: {search_string}\n")

    for i, abstract in enumerate(matched_abstracts.head(n), 1):
        print(f"{i}. {abstract}\n")

print_matching_abstracts_from_typology(sent_df, typology, solution_id=1, column="sentence", n=4)

# -----------------------------
# 8. store the result
# -----------------------------
# Select all columns ending with '_match' plus the 'id' column
match_cols = [col for col in sent_df.columns if col.endswith('_match')]
sent_df[match_cols] = sent_df[match_cols]*1
cols_to_save = ['id', 'sentence_id'] + match_cols

# Save to CSV
sent_df[cols_to_save].to_parquet("data/climate_solutions_typology/oa_sentence_solutions.parquet", index=False)

print(f"Saved {len(match_cols)} solution match columns + 'id' to oa_solutions.csv")
# Out:
# Searching for solution: Switch to cycling and walking
# Searching for solution: Highly accessible compact urban form and transit networks, and associated (AI-based) urban planning strategies
# Searching for solution: Uptake of BEVs and electric 2 and 3-wheelers
# Searching for solution: Switch to public transit
# Searching for solution: Low-carbon infrastructure materials
# Searching for solution: Shared mobility
# Searching for solution: Teleworking
# Searching for solution: Energy-efficient lifestyle
# Searching for solution: Compact urban form
# Searching for solution: High efficiency appliances
# Searching for solution: Limiting growth in floor space/sufficiency
# Searching for solution: Low-carbon building materials
# Searching for solution: Smart home systems (incl. smart thermostats and HVAC)
# Searching for solution: High-efficiency building envelopes and passive houses
# Searching for solution: Heat pumps and heat recovery systems
# Searching for solution: nZEBs
# Searching for solution: Citizen and renewable energy communities initiatives
# Searching for solution: District heating/cooling systems
# Searching for solution: Renewable electricity generation
# Searching for solution: Integrating renewable energy into infrastructure
# Searching for solution: Smart meters for VRE integration (including dynamic elec tariffs)
# Searching for solution: Grid reinforcement and storage
# Searching for solution: Hydrogen and e-fuels
# Searching for solution: Adaptive behavior and norms
# Searching for solution: Nature-based solutions, including blue-green infra
# Searching for solution: Albedo management
# Searching for solution: Heat shelters and cooling spaces
# Searching for solution: Diet shift
# Searching for solution: Enabling food sharing networks through digitalisation/partnership with the private sector
# Searching for solution: Tech advancement in food production and storage in urban scale
# Searching for solution: Reduced food waste, food sharing
# Searching for solution: Access to food during and post hazards
# Searching for solution: Growing food locally (urban and peri-urban agriculture)
# Searching for solution: Urban food environments
# Searching for solution: Water-saving practices and norms
# Searching for solution: Flood infrastructure: Sponge cities, dams, road elevation, …
# Searching for solution: Advanced control of the water supply system
# Searching for solution: Water-sensitive communities and community engagements
# Searching for solution: Droughts and water supply infrastructure: climate-resilient freshwater access and recycled water infrastructure
# Searching for solution: Access to safe and affordable WASH
# Searching for solution: Waste management practices and norms
# Searching for solution: Waste management infrastructure
# Searching for solution: Smart and digital waste management
# Searching for solution: Circular economy and industrial symbiosis
# Searching for solution: Adaptive behaviours and normative practices in disasters
# Searching for solution: Risk-sensitive planning and housing to reduce overall losses
# Searching for solution: early warning systems (including monitoring and management, digital and smart systems)
# Searching for solution: Access to social protection for vulnerable and informal residents
# Searching for solution: Insurance
# Searching for solution: Climate-resilient health care
# Searching for solution: Improved forest management, improved soil management by citizens
# Searching for solution: Urban forestry
# Searching for solution: BioCCS and DACCS
# Searching for solution: Biochar for urban soil applications
#                             sentence_id                                id  \
# 0   https://openalex.org/W4309037176_s1  https://openalex.org/W4309037176
# 1   https://openalex.org/W4309037176_s2  https://openalex.org/W4309037176
# 2   https://openalex.org/W4309037176_s3  https://openalex.org/W4309037176
# 3   https://openalex.org/W4309037176_s4  https://openalex.org/W4309037176
# 4   https://openalex.org/W4309037176_s5  https://openalex.org/W4309037176
# 5   https://openalex.org/W4309037176_s6  https://openalex.org/W4309037176
# 6   https://openalex.org/W4309037176_s7  https://openalex.org/W4309037176
# 7   https://openalex.org/W4309037176_s8  https://openalex.org/W4309037176
# 8    https://openalex.org/W180631480_s1   https://openalex.org/W180631480
# 9    https://openalex.org/W180631480_s2   https://openalex.org/W180631480
# 10   https://openalex.org/W180631480_s3   https://openalex.org/W180631480
# 11   https://openalex.org/W180631480_s4   https://openalex.org/W180631480
# 12   https://openalex.org/W180631480_s5   https://openalex.org/W180631480
# 13   https://openalex.org/W180631480_s6   https://openalex.org/W180631480
# 14   https://openalex.org/W180631480_s7   https://openalex.org/W180631480
# 15  https://openalex.org/W4388861001_s1  https://openalex.org/W4388861001
# 16  https://openalex.org/W4388861001_s2  https://openalex.org/W4388861001
# 17  https://openalex.org/W4388861001_s3  https://openalex.org/W4388861001
# 18  https://openalex.org/W4388861001_s4  https://openalex.org/W4388861001
# 19  https://openalex.org/W4388861001_s5  https://openalex.org/W4388861001
#
#                                              sentence  solution_1_match  \
# 0   Several chapters in the part 'Greening/rightsi...             False
# 1   The topic has recently come into focus, partic...             False
# 2   Resilience has many aspects, but two prominent...             False
# 3   This chapter deals with mitigation - specifica...             False
# 4     The analysis is divided into actions and tools.             False
# 5   Actions include: 1) smart regeneration on low-...             False
# 6   Tools cover the range of fiscal and bureaucrat...             False
# 7   These are illustrated by short examples from c...             False
# 8   The theme of Hyperbody this year is focused on...             False
# 9   Based on this theme, I chose one site in Beiji...             False
# 10  The site is surrounded by various land uses of...             False
# 11  Meanwhile, because of the existing traffic sit...             False
# 12  These implies a potential of interactivity wit...             False
# 13  And the environment parameters such as sunligh...             False
# 14  Thus, the design goal based on the theme of th...             False
# 15  Long-term high-resolution monitoring of aeroso...             False
# 16  Based on the 1 km AOD dataset retrieved by the...             False
# 17  In the past 20 years, the annual average AOD i...             False
# 18  The highest AOD of SCB in spring was 0.62, fol...             False
# 19  At the city scale, Zigong, Neijiang, and Ziyan...             False
#
#     solution_2_match  solution_3_match  solution_4_match  solution_5_match  \
# 0              False             False             False             False
# 1              False             False             False             False
# 2              False             False             False             False
# 3              False             False             False             False
# 4              False             False             False             False
# 5              False             False             False             False
# 6              False             False             False             False
# 7              False             False             False             False
# 8              False             False             False             False
# 9              False             False             False             False
# 10             False             False             False             False
# 11             False             False             False             False
# 12             False             False             False             False
# 13             False             False             False             False
# 14             False             False             False             False
# 15             False             False             False             False
# 16             False             False             False             False
# 17             False             False             False             False
# 18             False             False             False             False
# 19             False             False             False             False
#
#     solution_6_match  solution_7_match  ...  solution_45_match  \
# 0              False             False  ...              False
# 1              False             False  ...              False
# 2              False             False  ...              False
# 3              False             False  ...              False
# 4              False             False  ...              False
# 5              False             False  ...              False
# 6              False             False  ...              False
# 7              False             False  ...              False
# 8              False             False  ...              False
# 9              False             False  ...              False
# 10             False             False  ...              False
# 11             False             False  ...              False
# 12             False             False  ...              False
# 13             False             False  ...              False
# 14             False             False  ...              False
# 15             False             False  ...              False
# 16             False             False  ...              False
# 17             False             False  ...              False
# 18             False             False  ...              False
# 19             False             False  ...              False
#
#     solution_46_match  solution_47_match  solution_48_match  \
# 0               False              False              False
# 1               False              False              False
# 2               False              False              False
# 3               False              False              False
# 4               False              False              False
# 5               False              False              False
# 6               False              False              False
# 7               False              False              False
# 8               False              False              False
# 9               False              False              False
# 10              False              False              False
# 11              False              False              False
# 12              False              False              False
# 13              False              False              False
# 14              False              False              False
# 15              False              False              False
# 16              False              False              False
# 17              False              False              False
# 18              False              False              False
# 19              False              False              False
#
#     solution_49_match  solution_50_match  solution_51_match  \
# 0               False              False              False
# 1               False              False              False
# 2               False              False              False
# 3               False              False              False
# 4               False              False              False
# 5               False              False              False
# 6               False              False              False
# 7               False              False              False
# 8               False              False              False
# 9               False              False              False
# 10              False              False              False
# 11              False              False              False
# 12              False              False              False
# 13              False              False              False
# 14              False              False              False
# 15              False              False              False
# 16              False              False              False
# 17              False              False              False
# 18              False              False              False
# 19              False              False              False
#
#     solution_52_match  solution_53_match  solution_54_match
# 0               False              False              False
# 1               False              False              False
# 2               False              False              False
# 3               False              False              False
# 4               False              False              False
# 5                True              False              False
# 6               False              False              False
# 7               False              False              False
# 8               False              False              False
# 9               False              False              False
# 10              False              False              False
# 11              False              False              False
# 12              False              False              False
# 13              False              False              False
# 14              False              False              False
# 15              False              False              False
# 16              False              False              False
# 17              False              False              False
# 18              False              False              False
# 19              False              False              False
#
# [20 rows x 57 columns]

# %%
match_cols = [col for col in sent_df.columns if col.endswith('_match')]
print(sum(sent_df[match_cols].sum())/len(sent_df))
# Out:
# 0.029820597722057793

# %%
# Out:
# Looking for match column: solution_1_match
# 0    Switch to cycling and walking
# Name: solution_name, dtype: object
#
# --- Sample abstracts matching '0    Switch to cycling and walking
# Name: solution_name, dtype: object' ---
# Search query: ("transport" AND ("cycling" OR "cycle")) OR "bicycle" OR "bicycling" OR "bike" OR "bikes" OR "walk" OR "walkable" OR "walking" OR "pedestrian"
#
# 1. Making a city pedestrian-friendly has already been established as one of the major policy initiatives in urban planning and design.
#
# 2. This paper outlines three cases that are "Self-sufficient city" in Barcelona, "Superblock" also in Barcelona, and "Quarter-hour city", and discusses the underlying philosophy of the emerging pedestrian policies.
#
# 3. The chapter provides a close examination of the key design elements of the bicycle transportation system with a focus on the growth of the protected cycle track system.

# %%
# Out:
# solution_1_match: 0.002810738564466848
# solution_2_match: 0.004003373516134742
# solution_3_match: 0.0010317063907219488
# solution_4_match: 0.002837192574485359
# solution_5_match: 0.00020785293585973328
# solution_6_match: 0.0003212272645104969
# solution_7_match: 0.00013510440830882662
# solution_8_match: 6.267080944861655e-05
# solution_9_match: 0.0003476812745290084
# solution_10_match: 1.354193369995232e-05
# solution_11_match: 1.574643453482828e-06
# solution_12_match: 9.762789411593534e-06
# solution_13_match: 4.188551586264322e-05
# solution_14_match: 0.00029508818318268196
# solution_15_match: 0.00032154219320119345
# solution_16_match: 0.00012030275984608806
# solution_17_match: 6.267080944861655e-05
# solution_18_match: 0.0005149084092888847
# solution_19_match: 0.001041784108824239
# solution_20_match: 3.9366086337070694e-05
# solution_21_match: 7.558288576717573e-05
# solution_22_match: 0.0005149084092888847
# solution_23_match: 0.004803292390504018
# solution_24_match: 9.762789411593534e-05
# solution_25_match: 0.004886118636157215
# solution_26_match: 0.0008040129473483319
# solution_27_match: 8.50307464880727e-06
# solution_28_match: 9.227410637409372e-05
# solution_29_match: 9.132932030200402e-06
# solution_30_match: 1.574643453482828e-06
# solution_31_match: 1.4801648462738582e-05
# solution_32_match: 6.298573813931312e-07
# solution_33_match: 0.0007586632158880264
# solution_34_match: 1.3856862390648885e-05
# solution_35_match: 0.0005435669201422722
# solution_36_match: 0.00017919442500634582
# solution_37_match: 1.3856862390648885e-05
# solution_38_match: 4.409001669751918e-06
# solution_39_match: 1.133743286507636e-05
# solution_40_match: 0.0002021842194271951
# solution_41_match: 4.409001669751918e-05
# solution_42_match: 2.5194295255725247e-05
# solution_43_match: 1.2912076318559189e-05
# solution_44_match: 0.0007136284131184176
# solution_45_match: 4.314523062542948e-05
# solution_46_match: 2.204500834875959e-06
# solution_47_match: 0.00016659727737848318
# solution_48_match: 0.000108020540908922
# solution_49_match: 1.4486719772042017e-05
# solution_50_match: 4.723930360448483e-06
# solution_51_match: 0.0004339717357798674
# solution_52_match: 0.0005004216895168427
# solution_53_match: 0.00010266675316708038
# solution_54_match: 0.0003930310059893138

# %%
# Out:
# Saved 54 solution match columns + 'id' to oa_solutions.csv
